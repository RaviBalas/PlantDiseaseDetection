# %% [markdown]
# import os
# import tensorflow as tf
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
#
# In detail:-<br>
# 0 = all messages are logged (default behavior)<br>
# 1 = INFO messages are not printed<br>
# 2 = INFO and WARNING messages are not printed<br>
# 3 = INFO, WARNING, and ERROR messages are not printed<br>

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from keras.preprocessing import image
import keras
import numpy as np
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
os.listdir('mlmodel')
# Out:
# ['mTomato_model.h5', 'Tomato_model.h5']

# %%
print(np.__version__)
tf.__version__
# Out:
# 1.18.1
# '2.0.0-beta1'

# %%
model=tf.keras.models.load_model('mlmodel/mTomato_model.h5')
model.summary()
           x = image.img_to_array(img)
            x = np.expand_dims(x, axis=0)
            images = np.vstack([x])
            classes = model.predict(images)
# model=keras.models.load_model('./mlmodel/mTomato_model.h5')
# model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 254, 254, 128)     3584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 127, 127, 128)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 125, 125, 256)     295168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 62, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 60, 60, 512)       1180160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 30, 512)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 512)       2359808
# ...

# %%
l={0: 'Tomato___Bacterial_spot',
 1: 'Tomato___Early_blight',
 2: 'Tomato___Late_blight',
 3: 'Tomato___Leaf_Mold',
 4: 'Tomato___Septoria_leaf_spot',
 5: 'Tomato___Spider_mites Two-spotted_spider_mite',
 6: 'Tomato___Target_Spot',
 7: 'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
 8: 'Tomato___Tomato_mosaic_virus',
 9: 'Tomato___healthy'}

# %%
def predict_fun():
    model=tf.keras.models.load_model('./mlmodel/Tomato_model.h5')    
    try:
            img = image.load_img('./media/temp.jpg', target_size=(256, 256))    
            
            x = image.img_to_array(img)
            x = np.expand_dims(x, axis=0)
            images = np.vstack([x])
            classes = model.predict(images)
            x=(list(classes[0])).index(1)
            return str(x)
    except:
	    	return 403
predict_fun()
# Out:
# 403

# %%
# for fn in os.listdir('./media/'):
#         # predicting images
#         path = './media/'
#         print(path+fn)

for j in [i for i in os.listdir(r'C:\Users\RAVI-PC\Desktop') if i.endswith('jfif')]:
    img = image.load_img(r'C:\Users\RAVI-PC\Desktop/'+j, target_size=(256, 256))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    images = np.vstack([x])
    classes = model.predict(images)
    x=(list(classes[0])).index(1)
#     print(classes)
    print(j,"  ",x)
# Out:
# index.jfif    4
# Tomato___healthy.jfif    4
# Tomato___Leaf_Mold.jfif    4
# Tomato___Septoria_leaf_spot.jfif    4
# Tomato___Target_Spot.jfif    4

# %%
path = 'media'
img = image.load_img(path, target_size=(256, 256))
x = image.img_to_array(img)
# x = np.expand_dims(x, axis=0)
# images = np.vstack([x])
# classes = model.predict(images)
# print(fn)
# print(classes)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-a27cd8bb1a90> in <module>
#       1 path = 'media'
# ----> 2 img = image.load_img(path, target_size=(256, 256))
#       3 x = image.img_to_array(img)
#       4 # x = np.expand_dims(x, axis=0)
#       5 # images = np.vstack([x])
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras_preprocessing\image\utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     108         raise ImportError('Could not import PIL.Image. '
#     109                           'The use of `load_img` requires PIL.')
# --> 110     img = pil_image.open(path)
#     111     if color_mode == 'grayscale':
#     112         if img.mode != 'L':
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
# ...

# %%
[i for i in os.listdir() if i.endswith('jfif')]
# Out:
# ['download.jfif',
#  'Tomato___healthy.jfif',
#  'Tomato___Leaf_Mold.jfif',
#  'Tomato___Septoria_leaf_spot.jfif',
#  'Tomato___Target_Spot.jfif']

# %%
os.listdir()
# Out:
# ['00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_Bact.Sp 3110.JPG',
#  '009dd1f5-281a-4e54-9f80-a068d0d8cfcd___YLCV_NREC 2162.JPG',
#  '011e0c03-244b-4a90-b087-dececd2828fa___YLCV_NREC 2785.JPG',
#  '012ee431-b6ec-4dd5-8646-008bd2f554fe___YLCV_NREC 0064.JPG',
#  '01375198-62af-4c40-bddf-f3c11107200b___GCREC_Bact.Sp 5914.JPG',
#  '014d1604-dbbb-4b24-b167-37ec77cccfc6___UF.GRC_YLCV_Lab 01441.JPG',
#  '015f38c2-b5c3-47da-8130-87c810f2516c___YLCV_GCREC 2372.JPG',
#  '016bbee4-7b9d-40c8-a802-2bbf00f3bb27___YLCV_NREC 2290.JPG',
#  '018c1311-3ebf-48ce-8e31-f663e1b418a2___UF.GRC_YLCV_Lab 02979.JPG',
#  '018c6768-6da7-4aa8-8285-52290d8bffab___UF.GRC_YLCV_Lab 02344.JPG',
#  '020ff520-4b65-4f52-89b3-fe6ca90e0601___UF.GRC_YLCV_Lab 02220.JPG',
#  '023315df-8824-4760-9480-4dca3a023931___GHLB2 Leaf 8719.JPG',
#  '02626a44-a613-4402-a6b0-243858736e32___GCREC_Bact.Sp 3191.JPG',
#  '02790384-a589-421b-8695-693e77970418___GHLB2 Leaf 8920.JPG',
# ...

# %%
m=r'C:\Users\RAVI-PC\Desktop\PlantDiseaseDetection-master\PlantDiseaseDetection-master\dataset\test'

for j in [i for i in os.listdir(r'C:\Users\RAVI-PC\Desktop\PlantDiseaseDetection-master\PlantDiseaseDetection-master\dataset\test') if i.endswith('jpg')]:
    print(m+j)
# Out:
# C:\Users\RAVI-PC\Desktop\PlantDiseaseDetection-master\PlantDiseaseDetection-master\dataset\test10020ad2-c9bc-448b-a2de-7a8d34796f96___GHLB_PS Leaf 2.1 Day 13.jpg
# C:\Users\RAVI-PC\Desktop\PlantDiseaseDetection-master\PlantDiseaseDetection-master\dataset\test1159051e-1278-4b35-929c-e26b963d048f___GHLB_PS Leaf 8.1 Day 16.jpg
# C:\Users\RAVI-PC\Desktop\PlantDiseaseDetection-master\PlantDiseaseDetection-master\dataset\test121097dd-b0cb-436b-9b2f-7dab30c86872___GHLB_PS Leaf 37.1 Day 13.jpg
# C:\Users\RAVI-PC\Desktop\PlantDiseaseDetection-master\PlantDiseaseDetection-master\dataset\test12125c80-42e3-4970-bb92-524262c337fa___GHLB_PS Leaf 8.1 Day 7.jpg
# C:\Users\RAVI-PC\Desktop\PlantDiseaseDetection-master\PlantDiseaseDetection-master\dataset\test28130e0a-20fa-47bb-a995-74933946ff2f___GHLB_PS Leaf 24.4 Day 13.jpg
# C:\Users\RAVI-PC\Desktop\PlantDiseaseDetection-master\PlantDiseaseDetection-master\dataset\test35262a28-c600-4d1a-9179-f2e0d1638c08___GHLB_PS Leaf 42 Day 18.jpg
# ...

# %%
model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-1f8a688cae5d> in <module>
# ----> 1 model
#
# NameError: name 'model' is not defined
